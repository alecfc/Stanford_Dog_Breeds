# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from time import time
from glob import glob
from tqdm import tqdm
import os,shutil,math,scipy,cv2
import random as rn

from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix,roc_curve,auc

# %%
from keras.preprocessing.image import ImageDataGenerator as idg

# %%
tf.device('/device:GPU:0')

# %%
def label_assignment(img,label):
    return label

def training_data(label,data_dir):
    for img in tqdm(os.listdir(data_dir)):
        label = label_assignment(img,label)
        path = os.path.join(data_dir,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img,(imgsize,imgsize))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
chihuahua_dir = 'Images/n02085620_Chihuahua'
japanese_spaniel_dir = 'Images/n02085782_Japanese_spaniel'
maltese_dog_dir = 'Images/n02085936_Maltese_dog'
pekinese_dir = 'Images/n02086079_Pekinese'
shih_tzu_dir = 'Images/n02086240_Shih_Tzu'
blenheim_spaniel_dir = 'Images/n02086646_Blenheim_spaniel'
papillon_dir = 'Images/n02086910_papillon'
toy_terrier_dir = 'Images/n02087046_toy_terrier'
rhodesian_ridgeback_dir = 'Images/n02087394_Rhodesian_ridgeback'
afghan_hound_dir = 'Images/n02088094_Afghan_hound'
basset_dir = 'Images/n02088238_basset'
beagle_dir = 'Images/n02088364_beagle'
bloodhound_dir = 'Images/n02088466_bloodhound'
bluetick_dir = 'Images/n02088632_bluetick'
black_and_tan_coonhound_dir = 'Images/n02089078_black_and_tan_coonhound'
walker_hound_dir = 'Images/n02089867_Walker_hound'
english_foxhound_dir = 'Images/n02089973_English_foxhound'
redbone_dir = 'Images/n02090379_redbone'
borzoi_dir = 'Images/n02090622_borzoi'
irish_wolfhound_dir = 'Images/n02090721_Irish_wolfhound'
italian_greyhound_dir = 'Images/n02091032_Italian_greyhound'
whippet_dir = 'Images/n02091134_whippet'
ibizan_hound_dir = 'Images/n02091244_Ibizan_hound'
norwegian_elkhound_dir = 'Images/n02091467_Norwegian_elkhound'
otterhound_dir = 'Images/n02091635_otterhound'
saluki_dir = 'Images/n02091831_Saluki'
scottish_deerhound_dir = 'Images/n02092002_Scottish_deerhound'
weimaraner_dir = 'Images/n02092339_Weimaraner'
staffordshire_bullterrier_dir = 'Images/n02093256_Staffordshire_bullterrier'
american_staffordshire_terrier_dir = 'Images/n02093428_American_Staffordshire_terrier'
bedlington_terrier_dir = 'Images/n02093647_Bedlington_terrier'
border_terrier_dir = 'Images/n02093754_Border_terrier'
kerry_blue_terrier_dir = 'Images/n02093859_Kerry_blue_terrier'
irish_terrier_dir = 'Images/n02093991_Irish_terrier'
norfolk_terrier_dir = 'Images/n02094114_Norfolk_terrier'
norwich_terrier_dir = 'Images/n02094258_Norwich_terrier'
yorkshire_terrier_dir = 'Images/n02094433_Yorkshire_terrier'
wire_haired_fox_terrier_dir = 'Images/n02095314_wire_haired_fox_terrier'
lakeland_terrier_dir = 'Images/n02095570_Lakeland_terrier'
sealyham_terrier_dir = 'Images/n02095889_Sealyham_terrier'
airedale_dir = 'Images/n02096051_Airedale'
cairn_dir = 'Images/n02096177_cairn'
australian_terrier_dir = 'Images/n02096294_Australian_terrier'
dandie_dinmont_dir = 'Images/n02096437_Dandie_Dinmont'
boston_bull_dir = 'Images/n02096585_Boston_bull'
miniature_schnauzer_dir = 'Images/n02097047_miniature_schnauzer'
giant_schnauzer_dir = 'Images/n02097130_giant_schnauzer'
standard_schnauzer_dir = 'Images/n02097209_standard_schnauzer'
scotch_terrier_dir = 'Images/n02097298_Scotch_terrier'
tibetan_terrier_dir = 'Images/n02097474_Tibetan_terrier'
silky_terrier_dir = 'Images/n02097658_silky_terrier'
soft_coated_wheaten_terrier_dir = 'Images/n02098105_soft_coated_wheaten_terrier'
west_highland_white_terrier_dir = 'Images/n02098286_West_Highland_white_terrier'
lhasa_dir = 'Images/n02098413_Lhasa'
flat_coated_retriever_dir = 'Images/n02099267_flat_coated_retriever'
curly_coated_retriever_dir = 'Images/n02099429_curly_coated_retriever'
golden_retriever_dir = 'Images/n02099601_golden_retriever'
labrador_retriever_dir = 'Images/n02099712_Labrador_retriever'
chesapeake_bay_retriever_dir = 'Images/n02099849_Chesapeake_Bay_retriever'
german_short_haired_pointer_dir = 'Images/n02100236_German_short_haired_pointer'
vizsla_dir = 'Images/n02100583_vizsla'
english_setter_dir = 'Images/n02100735_English_setter'
irish_setter_dir = 'Images/n02100877_Irish_setter'
gordon_setter_dir = 'Images/n02101006_Gordon_setter'
brittany_spaniel_dir = 'Images/n02101388_Brittany_spaniel'
clumber_dir = 'Images/n02101556_clumber'
english_springer_dir = 'Images/n02102040_English_springer'
welsh_springer_spaniel_dir = 'Images/n02102177_Welsh_springer_spaniel'
cocker_spaniel_dir = 'Images/n02102318_cocker_spaniel'
sussex_spaniel_dir = 'Images/n02102480_Sussex_spaniel'
irish_water_spaniel_dir = 'Images/n02102973_Irish_water_spaniel'
kuvasz_dir = 'Images/n02104029_kuvasz'
schipperke_dir = 'Images/n02104365_schipperke'
groenendael_dir = 'Images/n02105056_groenendael'
malinois_dir = 'Images/n02105162_malinois'
briard_dir = 'Images/n02105251_briard'
kelpie_dir = 'Images/n02105412_kelpie'
komondor_dir = 'Images/n02105505_komondor'
old_english_sheepdog_dir = 'Images/n02105641_Old_English_sheepdog'
shetland_sheepdog_dir = 'Images/n02105855_Shetland_sheepdog'
collie_dir = 'Images/n02106030_collie'
border_collie_dir = 'Images/n02106166_Border_collie'
bouvier_des_flandres_dir = 'Images/n02106382_Bouvier_des_Flandres'
rottweiler_dir = 'Images/n02106550_Rottweiler'
german_shepherd_dir = 'Images/n02106662_German_shepherd'
doberman_dir = 'Images/n02107142_Doberman'
miniature_pinscher_dir = 'Images/n02107312_miniature_pinscher'
greater_swiss_mountain_dog_dir = 'Images/n02107574_Greater_Swiss_Mountain_dog'
bernese_mountain_dog_dir = 'Images/n02107683_Bernese_mountain_dog'
appenzeller_dir = 'Images/n02107908_Appenzeller'
entlebucher_dir = 'Images/n02108000_EntleBucher'
boxer_dir = 'Images/n02108089_boxer'
bull_mastiff_dir = 'Images/n02108422_bull_mastiff'
tibetan_mastiff_dir = 'Images/n02108551_Tibetan_mastiff'
french_bulldog_dir = 'Images/n02108915_French_bulldog'
great_dane_dir = 'Images/n02109047_Great_Dane'
saint_bernard_dir = 'Images/n02109525_Saint_Bernard'
eskimo_dog_dir = 'Images/n02109961_Eskimo_dog'
malamute_dir = 'Images/n02110063_malamute'
siberian_husky_dir = 'Images/n02110185_Siberian_husky'
affenpinscher_dir = 'Images/n02110627_affenpinscher'
basenji_dir = 'Images/n02110806_basenji'
pug_dir = 'Images/n02110958_pug'
leonberg_dir = 'Images/n02111129_Leonberg'
newfoundland_dir = 'Images/n02111277_Newfoundland'
great_pyrenees_dir = 'Images/n02111500_Great_Pyrenees'
samoyed_dir = 'Images/n02111889_Samoyed'
pomeranian_dir = 'Images/n02112018_Pomeranian'
chow_dir = 'Images/n02112137_chow'
keeshond_dir = 'Images/n02112350_keeshond'
brabancon_griffon_dir = 'Images/n02112706_Brabancon_griffon'
pembroke_dir = 'Images/n02113023_Pembroke'
cardigan_dir = 'Images/n02113186_Cardigan'
toy_poodle_dir = 'Images/n02113624_toy_poodle'
miniature_poodle_dir = 'Images/n02113712_miniature_poodle'
standard_poodle_dir = 'Images/n02113799_standard_poodle'
mexican_hairless_dir = 'Images/n02113978_Mexican_hairless'
dingo_dir = 'Images/n02115641_dingo'
dhole_dir = 'Images/n02115913_dhole'
african_hunting_dog_dir = 'Images/n02116738_African_hunting_dog'

X = []
Z = []
imgsize = 150

# %%
training_data('chihuahua',chihuahua_dir)
training_data('japanese_spaniel',japanese_spaniel_dir)
training_data('maltese_dog',maltese_dog_dir)
training_data('pekinese',pekinese_dir)
training_data('shih-tzu',shih_tzu_dir)
training_data('blenheim_spaniel',blenheim_spaniel_dir)
training_data('papillon',papillon_dir)
training_data('toy_terrier',toy_terrier_dir)
training_data('rhodesian_ridgeback',rhodesian_ridgeback_dir)
training_data('afghan_hound',afghan_hound_dir)
training_data('basset',basset_dir)
training_data('beagle',beagle_dir)
training_data('bloodhound',bloodhound_dir)
training_data('bluetick',bluetick_dir)
training_data('black-and-tan_coonhound',black_and_tan_coonhound_dir)
training_data('walker_hound',walker_hound_dir)
training_data('english_foxhound',english_foxhound_dir)
training_data('redbone',redbone_dir)
training_data('borzoi',borzoi_dir)
training_data('irish_wolfhound',irish_wolfhound_dir)
training_data('italian_greyhound',italian_greyhound_dir)
training_data('whippet',whippet_dir)
training_data('ibizan_hound',ibizan_hound_dir)
training_data('norwegian_elkhound',norwegian_elkhound_dir)
training_data('otterhound',otterhound_dir)
training_data('saluki',saluki_dir)
training_data('scottish_deerhound',scottish_deerhound_dir)
training_data('weimaraner',weimaraner_dir)
training_data('staffordshire_bullterrier',staffordshire_bullterrier_dir)
training_data('american_staffordshire_terrier',american_staffordshire_terrier_dir)
training_data('bedlington_terrier',bedlington_terrier_dir)
training_data('border_terrier',border_terrier_dir)
training_data('kerry_blue_terrier',kerry_blue_terrier_dir)
training_data('irish_terrier',irish_terrier_dir)
training_data('norfolk_terrier',norfolk_terrier_dir)
training_data('norwich_terrier',norwich_terrier_dir)
training_data('yorkshire_terrier',yorkshire_terrier_dir)
training_data('wire-haired_fox_terrier',wire_haired_fox_terrier_dir)
training_data('lakeland_terrier',lakeland_terrier_dir)
training_data('sealyham_terrier',sealyham_terrier_dir)
training_data('airedale',airedale_dir)
training_data('cairn',cairn_dir)
training_data('australian_terrier',australian_terrier_dir)
training_data('dandie_dinmont',dandie_dinmont_dir)
training_data('boston_bull',boston_bull_dir)
training_data('miniature_schnauzer',miniature_schnauzer_dir)
training_data('giant_schnauzer',giant_schnauzer_dir)
training_data('standard_schnauzer',standard_schnauzer_dir)
training_data('scotch_terrier',scotch_terrier_dir)
training_data('tibetan_terrier',tibetan_terrier_dir)
training_data('silky_terrier',silky_terrier_dir)
training_data('soft-coated_wheaten_terrier',soft_coated_wheaten_terrier_dir)
training_data('west_highland_white_terrier',west_highland_white_terrier_dir)
training_data('lhasa',lhasa_dir)
training_data('flat-coated_retriever',flat_coated_retriever_dir)
training_data('curly-coated_retriever',curly_coated_retriever_dir)
training_data('golden_retriever',golden_retriever_dir)
training_data('labrador_retriever',labrador_retriever_dir)
training_data('chesapeake_bay_retriever',chesapeake_bay_retriever_dir)
training_data('german_short-haired_pointer',german_short_haired_pointer_dir)
training_data('vizsla',vizsla_dir)
training_data('english_setter',english_setter_dir)
training_data('irish_setter',irish_setter_dir)
training_data('gordon_setter',gordon_setter_dir)
training_data('brittany_spaniel',brittany_spaniel_dir)
training_data('clumber',clumber_dir)
training_data('english_springer',english_springer_dir)
training_data('welsh_springer_spaniel',welsh_springer_spaniel_dir)
training_data('cocker_spaniel',cocker_spaniel_dir)
training_data('sussex_spaniel',sussex_spaniel_dir)
training_data('irish_water_spaniel',irish_water_spaniel_dir)
training_data('kuvasz',kuvasz_dir)
training_data('schipperke',schipperke_dir)
training_data('groenendael',groenendael_dir)
training_data('malinois',malinois_dir)
training_data('briard',briard_dir)
training_data('kelpie',kelpie_dir)
training_data('komondor',komondor_dir)
training_data('old_english_sheepdog',old_english_sheepdog_dir)
training_data('shetland_sheepdog',shetland_sheepdog_dir)
training_data('collie',collie_dir)
training_data('border_collie',border_collie_dir)
training_data('bouvier_des_flandres',bouvier_des_flandres_dir)
training_data('rottweiler',rottweiler_dir)
training_data('german_shepherd',german_shepherd_dir)
training_data('doberman',doberman_dir)
training_data('miniature_pinscher',miniature_pinscher_dir)
training_data('greater_swiss_mountain_dog',greater_swiss_mountain_dog_dir)
training_data('bernese_mountain_dog',bernese_mountain_dog_dir)
training_data('appenzeller',appenzeller_dir)
training_data('entlebucher',entlebucher_dir)
training_data('boxer',boxer_dir)
training_data('bull_mastiff',bull_mastiff_dir)
training_data('tibetan_mastiff',tibetan_mastiff_dir)
training_data('french_bulldog',french_bulldog_dir)
training_data('great_dane',great_dane_dir)
training_data('saint_bernard',saint_bernard_dir)
training_data('eskimo_dog',eskimo_dog_dir)
training_data('malamute',malamute_dir)
training_data('siberian_husky',siberian_husky_dir)
training_data('affenpinscher',affenpinscher_dir)
training_data('basenji',basenji_dir)
training_data('pug',pug_dir)
training_data('leonberg',leonberg_dir)
training_data('newfoundland',newfoundland_dir)
training_data('great_pyrenees',great_pyrenees_dir)
training_data('samoyed',samoyed_dir)
training_data('pomeranian',pomeranian_dir)
training_data('chow',chow_dir)
training_data('keeshond',keeshond_dir)
training_data('brabancon_griffon',brabancon_griffon_dir)
training_data('pembroke',pembroke_dir)
training_data('cardigan',cardigan_dir)
training_data('toy_poodle',toy_poodle_dir)
training_data('miniature_poodle',miniature_poodle_dir)
training_data('standard_poodle',standard_poodle_dir)
training_data('mexican_hairless',mexican_hairless_dir)
training_data('dingo',dingo_dir)
training_data('dhole',dhole_dir)
training_data('african_hunting_dog',african_hunting_dog_dir)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 169/169 [00:00<00:00, 268.54it/s]

# %%
label_encoder= LabelEncoder()
Y = label_encoder.fit_transform(Z)
Y = keras.utils.to_categorical(Y,120)
X = np.array(X)
X=X/255

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=69)

# %%
model = keras.models.Sequential()

# %%
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model.add(keras.layers.MaxPooling2D((2, 2)))
model.add(keras.layers.Conv2D(128, (3, 3), activation='relu'))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.MaxPooling2D((2, 2)))
model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.MaxPooling2D((2, 2)))
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.MaxPooling2D((2, 2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(512, activation='relu'))
model.add(keras.layers.Dense(120, activation='softmax'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, batch_size=16, validation_split=0.2, verbose=2)
# Out:
# Train on 11524 samples, validate on 2882 samples
# Epoch 1/10

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()
